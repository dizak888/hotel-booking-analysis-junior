# %%
import pandas as pd

# %%
path_to_file ='2_bookings.csv'

# %%
df=pd.read_csv(path_to_file,sep=';')

# %%
df.head(7)
# Out:
#           Hotel  Is Canceled  Lead Time arrival full date  Arrival Date Year  \
# 0  Resort Hotel            0        342        2015-07-01               2015
# 1  Resort Hotel            0        737        2015-07-01               2015
# 2  Resort Hotel            0          7        2015-07-01               2015
# 3  Resort Hotel            0         13        2015-07-01               2015
# 4  Resort Hotel            0         14        2015-07-01               2015
# 5  Resort Hotel            0         14        2015-07-01               2015
# 6  Resort Hotel            0          0        2015-07-01               2015
#
#   Arrival Date Month  Arrival Date Week Number  Arrival Date Day of Month  \
# 0               July                        27                          1
# 1               July                        27                          1
# 2               July                        27                          1
# ...

# %%
df.columns = df.columns.str.lower().str.replace(' ', '_')

# %%
df
# Out:
#                hotel  is_canceled  lead_time arrival_full_date  \
# 0       Resort Hotel            0        342        2015-07-01
# 1       Resort Hotel            0        737        2015-07-01
# 2       Resort Hotel            0          7        2015-07-01
# 3       Resort Hotel            0         13        2015-07-01
# 4       Resort Hotel            0         14        2015-07-01
# ...              ...          ...        ...               ...
# 119385    City Hotel            0         23        2017-08-30
# 119386    City Hotel            0        102        2017-08-31
# 119387    City Hotel            0         34        2017-08-31
# 119388    City Hotel            0        109        2017-08-31
# 119389    City Hotel            0        205        2017-08-29
#
#         arrival_date_year arrival_date_month  arrival_date_week_number  \
# 0                    2015               July                        27
# ...

# %%
top5=df[df['is_canceled']==0]['country'].value_counts().head(5)

# %%
top5
# Out:
# country
# PRT    21071
# GBR     9676
# FRA     8481
# ESP     6391
# DEU     6069
# Name: count, dtype: int64

# %%
df.groupby('hotel').stays_total_nights.mean()
# Out:
# hotel
# City Hotel      2.978142
# Resort Hotel    4.318547
# Name: stays_total_nights, dtype: float64

# %%
(df['assigned_room_type']!=df['reserved_room_type']).sum()
# Out:
# np.int64(14917)

# %%
df[df['assigned_room_type'] != df['reserved_room_type']].groupby('hotel').size()
# Out:
# hotel
# City Hotel      7192
# Resort Hotel    7725
# dtype: int64

# %%
succ=df[df['is_canceled']==0]

# %%
succ
# Out:
#                hotel  is_canceled  lead_time arrival_full_date  \
# 0       Resort Hotel            0        342        2015-07-01
# 1       Resort Hotel            0        737        2015-07-01
# 2       Resort Hotel            0          7        2015-07-01
# 3       Resort Hotel            0         13        2015-07-01
# 4       Resort Hotel            0         14        2015-07-01
# ...              ...          ...        ...               ...
# 119385    City Hotel            0         23        2017-08-30
# 119386    City Hotel            0        102        2017-08-31
# 119387    City Hotel            0         34        2017-08-31
# 119388    City Hotel            0        109        2017-08-31
# 119389    City Hotel            0        205        2017-08-29
#
#         arrival_date_year arrival_date_month  arrival_date_week_number  \
# 0                    2015               July                        27
# ...

# %%
pop2016=succ[succ['arrival_date_year']==2016]['arrival_date_month'].value_counts().idxmax()

# %%
pop2016
# Out:
# 'October'

# %%
pop2017=succ[succ['arrival_date_year']==2017]['arrival_date_month'].value_counts().idxmax()

# %%
pop2017
# Out:
# 'May'

# %%
canceled=df[df['is_canceled']==1].groupby('arrival_date_year')

# %%
canceled = df[(df['is_canceled'] == 1) & (df['hotel'] == 'City Hotel')]

# %%
canceled
# Out:
#              hotel  is_canceled  lead_time arrival_full_date  \
# 40061   City Hotel            1         88        2015-07-01
# 40062   City Hotel            1         65        2015-07-01
# 40063   City Hotel            1         92        2015-07-01
# 40064   City Hotel            1        100        2015-07-02
# 40065   City Hotel            1         79        2015-07-02
# ...            ...          ...        ...               ...
# 110280  City Hotel            1        132        2017-04-25
# 111355  City Hotel            1          4        2017-06-05
# 111924  City Hotel            1          7        2017-05-31
# 111925  City Hotel            1          6        2017-07-17
# 117295  City Hotel            1          0        2017-08-02
#
#         arrival_date_year arrival_date_month  arrival_date_week_number  \
# 40061                2015               July                        27
# 40062                2015               July                        27
# ...

# %%
canceled = df[(df['is_canceled'] == 1) & (df['hotel'] == 'City Hotel')].groupby('arrival_date_year')['arrival_date_month'].agg(lambda x: x.value_counts().idxmax())

# %%
canceled
# Out:
# arrival_date_year
# 2015    September
# 2016      October
# 2017          May
# Name: arrival_date_month, dtype: object

# %%
df[['adults','children','babies']].mean()
# Out:
# adults      1.856403
# children    0.103890
# babies      0.007949
# dtype: float64

# %%
df['total_kids']=df['children']+df['babies']

# %%
df.groupby('hotel')['total_kids'].mean().idxmax()
# Out:
# 'Resort Hotel'

# %%
df['total_kids']>0['has_kids']==1
